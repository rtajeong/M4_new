# %% [markdown]
# # Yolov3 연습
# - different platform
# - Pytorch with CUDA

# %%
import sys
print(sys.version)
# Out:
# 3.8.16 (default, Dec  7 2022, 01:12:13)
# [GCC 7.5.0]

# %%
# !git clone https://github.com/ultralytics/yolov3.git
# %cd yolov3
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 10079, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 10079 (delta 30), reused 31 (delta 13), pack-reused 10017
# Receiving objects: 100% (10079/10079), 9.39 MiB | 25.05 MiB/s, done.
# Resolving deltas: 100% (6788/6788), done.
# /content/yolov3

# %%
# !pwd
# Out:
# /content/yolov3

# %%
# do not the following any more (automatically downloaded)
# !chmod +x weights/download_weights.sh
# !weights/download_weights.sh

# %%
# !pwd
# Out:
# /content/yolov3

# %%
# !ls -l weights
# Out:
# ls: cannot access 'weights': No such file or directory

# %%
# !python3 detect.py --weights yolov3-spp.pt
# Out:
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# detect: weights=['yolov3-spp.pt'], source=data/images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# requirements: ipython not found and is required by YOLOv3, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (7.9.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 35.7 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython) (57.4.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython) (5.7.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython) (2.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython) (0.7.0)
# Installing collected packages: jedi
# Successfully installed jedi-0.18.2
#
# requirements: 1 package updated per /content/yolov3/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv3 🚀 v9.6.0-32-gae460cf torch 1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Downloading https://github.com/ultralytics/yolov3/releases/download/v9.6.0/yolov3-spp.pt to yolov3-spp.pt...
# 100% 121M/121M [00:05<00:00, 25.2MB/s]
#
# Fusing layers...
# Model Summary: 269 layers, 62971933 parameters, 0 gradients
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bus, 1 tie, Done. (0.055s)
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 2 persons, 3 ties, 1 tennis racket, Done. (0.048s)
# Speed: 0.6ms pre-process, 51.6ms inference, 18.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
# !python3 detect.py --help
# Out:
# usage: detect.py
#        [-h]
#        [--weights WEIGHTS [WEIGHTS ...]]
#        [--source SOURCE]
#        [--imgsz IMGSZ [IMGSZ ...]]
#        [--conf-thres CONF_THRES]
#        [--iou-thres IOU_THRES]
#        [--max-det MAX_DET]
#        [--device DEVICE]
#        [--view-img]
#        [--save-txt]
#        [--save-conf]
#        [--save-crop]
#        [--nosave]
#        [--classes CLASSES [CLASSES ...]]
#        [--agnostic-nms]
#        [--augment]
#        [--visualize]
#        [--update]
#        [--project PROJECT]
#        [--name NAME]
#        [--exist-ok]
#        [--line-thickness LINE_THICKNESS]
#        [--hide-labels]
#        [--hide-conf]
#        [--half]
#        [--dnn]
#
# optional arguments:
#   -h, --help
#     show this
#     help
#     message and
#     exit
#   --weights WEIGHTS [WEIGHTS ...]
#     model
#     path(s)
#   --source SOURCE
#     file/dir/UR
#     L/glob, 0
#     for webcam
#   --imgsz IMGSZ [IMGSZ ...], --img IMGSZ [IMGSZ ...], --img-size IMGSZ [IMGSZ ...]
#     inference
#     size h,w
#   --conf-thres CONF_THRES
#     confidence
#     threshold
#   --iou-thres IOU_THRES
#     NMS IoU
#     threshold
#   --max-det MAX_DET
#     maximum
#     detections
#     per image
#   --device DEVICE
#     cuda
#     device,
#     i.e. 0 or
#     0,1,2,3 or
#     cpu
#   --view-img
#     show
#     results
#   --save-txt
#     save
#     results to
#     *.txt
#   --save-conf
#     save
#     confidences
#     in --save-
#     txt labels
#   --save-crop
#     save
#     cropped
#     prediction
#     boxes
#   --nosave
#     do not save
#     images/vide
#     os
#   --classes CLASSES [CLASSES ...]
#     filter by
#     class:
#     --classes
#     0, or
#     --classes 0
#     2 3
#   --agnostic-nms
#     class-
#     agnostic
#     NMS
#   --augment
#     augmented
#     inference
#   --visualize
#     visualize
#     features
#   --update
#     update all
#     models
#   --project PROJECT
#     save
#     results to
#     project/nam
#     e
#   --name NAME
#     save
#     results to
#     project/nam
#     e
#   --exist-ok
#     existing pr
#     oject/name
#     ok, do not
#     increment
#   --line-thickness LINE_THICKNESS
#     bounding
#     box
#     thickness
#     (pixels)
#   --hide-labels
#     hide labels
#   --hide-conf
#     hide
#     confidences
#   --half
#     use FP16
#     half-
#     precision
#     inference
#   --dnn
#     use OpenCV
#     DNN for
#     ONNX
#     inference

# %%
# !pwd
# Out:
# /content/yolov3

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('./runs/detect/exp/bus.jpg')
plt.imshow(img)

# %%
img = mpimg.imread('./runs/detect/exp/zidane.jpg')
plt.imshow(img)

# %% [markdown]
# ### Using Yolov3-tiny

# %%
# !python3 detect.py --weights yolov3-tiny.pt
img = mpimg.imread('./runs/detect/exp/bus.jpg')
plt.imshow(img)
# Out:
# detect: weights=['yolov3-tiny.pt'], source=data/images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-32-gae460cf torch 1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Downloading https://github.com/ultralytics/yolov3/releases/download/v9.6.0/yolov3-tiny.pt to yolov3-tiny.pt...
# 100% 17.0M/17.0M [00:01<00:00, 12.7MB/s]
#
# Fusing layers...
# Model Summary: 48 layers, 8849182 parameters, 0 gradients
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 1 surfboard, Done. (0.024s)
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 3 persons, 1 tie, Done. (0.027s)
# Speed: 1.8ms pre-process, 25.4ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
img = mpimg.imread('./runs/detect/exp/zidane.jpg')
plt.imshow(img)

# %%
# !python3 detect.py --weights yolov3.pt
img = mpimg.imread('./runs/detect/exp/bus.jpg')
plt.imshow(img)
# Out:
# detect: weights=['yolov3.pt'], source=data/images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-32-gae460cf torch 1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Downloading https://github.com/ultralytics/yolov3/releases/download/v9.6.0/yolov3.pt to yolov3.pt...
# 100% 119M/119M [00:05<00:00, 22.5MB/s]
#
# Fusing layers...
# Model Summary: 261 layers, 61922845 parameters, 0 gradients
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bicycle, 1 bus, Done. (0.050s)
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.040s)
# Speed: 0.5ms pre-process, 44.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
img = mpimg.imread('./runs/detect/exp/zidane.jpg')
plt.imshow(img)

# %%
# !pwd
# Out:
# /content/yolov3
